# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\Users\Gaurish16\OneDrive\Desktop\Udemy\venv\Lib\site-packages (from gensim) (2.4.1)
# Requirement already satisfied: scipy>=1.7.0 in c:\Users\Gaurish16\OneDrive\Desktop\Udemy\venv\Lib\site-packages (from gensim) (1.17.0)
# Collecting smart_open>=1.8.1 (from gensim)
#   Downloading smart_open-7.6.1-py3-none-any.whl.metadata (25 kB)
# Collecting wrapt (from smart_open>=1.8.1->gensim)
#   Downloading wrapt-2.2.1-cp312-cp312-win_amd64.whl.metadata (7.6 kB)
# Downloading gensim-4.4.0-cp312-cp312-win_amd64.whl (24.4 MB)
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    - -------------------------------------- 0.8/24.4 MB 8.3 MB/s eta 0:00:03
#    --- ------------------------------------ 1.8/24.4 MB 4.8 MB/s eta 0:00:05
#    --- ------------------------------------ 2.4/24.4 MB 3.7 MB/s eta 0:00:06
#    ------ --------------------------------- 3.7/24.4 MB 4.3 MB/s eta 0:00:05
#    ------- -------------------------------- 4.5/24.4 MB 4.3 MB/s eta 0:00:05
#    -------- ------------------------------- 5.2/24.4 MB 4.2 MB/s eta 0:00:05
#    --------- ------------------------------ 6.0/24.4 MB 4.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 6.8/24.4 MB 4.1 MB/s eta 0:00:05
#    ------------ --------------------------- 7.9/24.4 MB 4.1 MB/s eta 0:00:05
#    -------------- ------------------------- 8.7/24.4 MB 4.1 MB/s eta 0:00:04
#    --------------- ------------------------ 9.4/24.4 MB 4.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 10.2/24.4 MB 4.1 MB/s eta 0:00:04
#    ------------------ --------------------- 11.0/24.4 MB 4.0 MB/s eta 0:00:04
#    ------------------- -------------------- 12.1/24.4 MB 4.0 MB/s eta 0:00:04
#    --------------------- ------------------ 12.8/24.4 MB 4.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 13.6/24.4 MB 4.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 14.4/24.4 MB 4.0 MB/s eta 0:00:03
#    ------------------------ --------------- 15.2/24.4 MB 4.0 MB/s eta 0:00:03
#    -------------------------- ------------- 16.0/24.4 MB 4.0 MB/s eta 0:00:03
#    --------------------------- ------------ 16.8/24.4 MB 4.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 17.8/24.4 MB 4.0 MB/s eta 0:00:02
#    ------------------------------ --------- 18.6/24.4 MB 4.0 MB/s eta 0:00:02
#    ------------------------------- -------- 19.4/24.4 MB 4.0 MB/s eta 0:00:02
#    --------------------------------- ------ 20.2/24.4 MB 4.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.0/24.4 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.8/24.4 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 22.8/24.4 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.6/24.4 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  24.4/24.4 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 24.4/24.4 MB 3.9 MB/s  0:00:06
# Downloading smart_open-7.6.1-py3-none-any.whl (64 kB)
# Downloading wrapt-2.2.1-cp312-cp312-win_amd64.whl (80 kB)
# Installing collected packages: wrapt, smart_open, gensim
#
#    ---------------------------------------- 0/3 [wrapt]
#    ------------- -------------------------- 1/3 [smart_open]
#    ------------- -------------------------- 1/3 [smart_open]
#    ------------- -------------------------- 1/3 [smart_open]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    ---------------------------------------- 3/3 [gensim]
#
# Successfully installed gensim-4.4.0 smart_open-7.6.1 wrapt-2.2.1
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
## References: https://stackoverflow.com/questions/46433778/import-googlenews-vectors-negative300-bin

# %%
import gensim.downloader as api
print(api.info()['models'].keys())
# Out:
# dict_keys(['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis'])

# %%
import gensim.downloader as api

wv = api.load("glove-wiki-gigaword-50")
print(wv["king"])
# Out:
# [==================================================] 100.0% 66.0/66.0MB downloaded
# [ 0.50451   0.68607  -0.59517  -0.022801  0.60046  -0.13498  -0.08813
#   0.47377  -0.61798  -0.31012  -0.076666  1.493    -0.034189 -0.98173
#   0.68229   0.81722  -0.51874  -0.31503  -0.55809   0.66421   0.1961
#  -0.13495  -0.11476  -0.30344   0.41177  -2.223    -1.0756   -1.0783
#  -0.34354   0.33505   1.9927   -0.04234  -0.64319   0.71125   0.49159
#   0.16754   0.34344  -0.25663  -0.8523    0.1661    0.40102   1.1685
#  -1.0137   -0.21585  -0.15155   0.78321  -0.91241  -1.6106   -0.64426
#  -0.51042 ]

# %%
import gensim.downloader as api
wv = api.load("glove-wiki-gigaword-100")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
vec_king = wv['king']

# %%
vec_king
# Out:
# array([-0.32307 , -0.87616 ,  0.21977 ,  0.25268 ,  0.22976 ,  0.7388  ,
#        -0.37954 , -0.35307 , -0.84369 , -1.1113  , -0.30266 ,  0.33178 ,
#        -0.25113 ,  0.30448 , -0.077491, -0.89815 ,  0.092496, -1.1407  ,
#        -0.58324 ,  0.66869 , -0.23122 , -0.95855 ,  0.28262 , -0.078848,
wv.most_similar('cricket')
# Out:
# [('rugby', 0.7827098369598389),
#  ('twenty20', 0.7362942099571228),
#  ('england', 0.7173773646354675),
#  ('indies', 0.715782105922699),
#  ('cricketers', 0.7132172584533691),
#  ('football', 0.6659637093544006),
#  ('zealand', 0.6606222987174988),
#  ('matches', 0.6509107351303101),
#  ('bowling', 0.6504763960838318),
#  ('wc2003-wis', 0.642265260219574)]

# %%
wv.most_similar('happy')
# Out:
# [("'m", 0.8413287997245789),
#  ('feel', 0.8132575750350952),
#  ("'re", 0.8048083186149597),
#  ('i', 0.7938276529312134),
#  ("'ll", 0.7916273474693298),
#  ('really', 0.7903971076011658),
#  ('glad', 0.7833361029624939),
#  ('good', 0.7821646332740784),
#  ('we', 0.7808917164802551),
#  ('sure', 0.7788466215133667)]

# %%
wv.similarity("hockey","sports")
# Out:
# np.float32(0.6193382)

# %%
vec=wv['king']-wv['man']+wv['woman']

# %%
vec
# Out:
# array([-0.10231996, -0.81294006,  0.10211003,  0.985924  ,  0.34218282,
#         1.09095   , -0.48912996, -0.05616698, -0.21029997, -1.02996   ,
#        -0.86851   ,  0.36786997,  0.01960999,  0.59259   , -0.23190099,
#        -1.016919  , -0.01218399, -1.17194   , -0.52329   ,  0.60645   ,
#        -0.98537004, -1.001028  ,  0.48913902,  0.630072  ,  0.58224   ,
#         0.15908998,  0.43685   , -1.25351   ,  0.97054   , -0.065529  ,
#         0.733763  ,  0.44219002,  1.2091839 ,  0.19698   , -0.15948   ,
#         0.34364003, -0.46222997,  0.33772   ,  0.14792705, -0.24959502,
#        -0.77093005,  0.522717  , -0.1283    , -0.91881   , -0.01755001,
#        -0.44041002, -0.52656496,  0.33734798,  0.60639   , -0.45067   ,
#        -0.04158002,  0.08408299,  1.31456   ,  0.67737997, -0.24316001,
#        -2.071     , -0.60648996,  0.19710997,  0.63567   ,  0.07819998,
#         0.49161002,  0.08171999,  0.70855707,  0.201938  ,  0.5155501 ,
#        -0.23025298, -0.40473002,  0.39212003, -0.5093    , -0.139153  ,
#         0.21609999, -0.628671  ,  0.08894002,  0.49167   , -0.06637001,
#         0.76095   , -0.19442001,  0.41131002, -1.04476   , -0.14801991,
#        -0.09835501, -0.25115   ,  0.808957  ,  0.36312902, -0.78200996,
#        -0.10484004,  0.08340102, -1.24067   ,  0.655344  , -0.93635   ,
#         0.648379  , -0.55827   ,  0.45621303,  0.27575803, -1.54896   ,
#        -0.199096  , -0.50804996, -0.13818002,  0.27731198, -0.75721   ],
#       dtype=float32)

# %%
wv.most_similar([vec])
# Out:
# [('king', 0.8551837205886841),
#  ('queen', 0.783441424369812),
#  ('monarch', 0.6933802366256714),
#  ('throne', 0.6833109855651855),
#  ('daughter', 0.6809081435203552),
#  ('prince', 0.6713141798973083),
#  ('princess', 0.664408266544342),
#  ('mother', 0.6579325795173645),
#  ('elizabeth', 0.6563301086425781),
#  ('father', 0.6392418742179871)]
